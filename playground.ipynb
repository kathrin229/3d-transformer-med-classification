# %%
# %%bash
# wget -c http://47.92.107.188/Datasets/COVID-DATA-CT/dataset_seg.tar.gz

# %%
# import tarfile
  
# file = tarfile.open('dataset_seg.tar.gz')
# file.extractall('./data')
  
# file.close()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img

path = '../../data/dataset_seg/CP/1065/3104/0022.png'

image = img.imread(path)
plt.imshow(image)
plt.show()

# %%
# print one 3D lung
fig = plt.figure(figsize=(12, 12))
columns = 5
rows = 11
path = '../../data/dataset_seg/CP/1065/3104/00'
for i in range(1, columns*rows +1):
    if i-1 < 10:
        image = img.imread(path+'0'+str(i-1)+".png")
    else:
        image = img.imread(path+str(i-1)+".png")
    fig.add_subplot(rows, columns, i)
    plt.imshow(image)
plt.show()

# %%
# loop through dataset
import os

rootdir = '../../data/dataset_seg/CP'#/1065/3104'
import os
# Out:
# ./Data_seg/dataset_seg/CP/3766
# ./Data_seg/dataset_seg/CP/1627
# ./Data_seg/dataset_seg/CP/1169
# ./Data_seg/dataset_seg/CP/667
# ./Data_seg/dataset_seg/CP/1314
# ./Data_seg/dataset_seg/CP/3763
# ./Data_seg/dataset_seg/CP/1520
# ./Data_seg/dataset_seg/CP/1490
# ./Data_seg/dataset_seg/CP/3793
# ./Data_seg/dataset_seg/CP/1218
# ./Data_seg/dataset_seg/CP/1501
# ./Data_seg/dataset_seg/CP/1322
# ./Data_seg/dataset_seg/CP/3794
# ./Data_seg/dataset_seg/CP/3807
# ./Data_seg/dataset_seg/CP/1769
# ./Data_seg/dataset_seg/CP/1598
# ./Data_seg/dataset_seg/CP/1108
# ./Data_seg/dataset_seg/CP/1527
# ./Data_seg/dataset_seg/CP/1581
# ./Data_seg/dataset_seg/CP/1505
# ./Data_seg/dataset_seg/CP/1599
# ./Data_seg/dataset_seg/CP/1266
# ./Data_seg/dataset_seg/CP/3824
# ./Data_seg/dataset_seg/CP/1473
# ./Data_seg/dataset_seg/CP/735
# ./Data_seg/dataset_seg/CP/1543
# ./Data_seg/dataset_seg/CP/1229
# ./Data_seg/dataset_seg/CP/1424
# ./Data_seg/dataset_seg/CP/2757
# ./Data_seg/dataset_seg/CP/612
# ...
